# %% [markdown]
# Import Libraries

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# Read in the EDGE file

# %%
g=nx.read_edgelist("data/facebook/facebook/0.edges")

# %% [markdown]
# Print out the graph summary

# %%
print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 333
# Number of edges: 2519
# Average degree:  15.1291

# %% [markdown]
# Plot the graph
#
# -NetworkX said they are no longer focusing on graph visualizations and to use other visualization packages. The graph below is very poor and Gephi was later used.

# %%
nx.draw(g)
#plt.show()
# Out:
# c:\users\michel~1\docume~1\data62~1\venv\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# Gephi full display

# %% [markdown]
# ![facebook%20edges.PNG](attachment:facebook%20edges.PNG)

# %% [markdown]
# One node selected (129) showing the edges for that node.

# %% [markdown]
# ![node.png](attachment:node.png)
